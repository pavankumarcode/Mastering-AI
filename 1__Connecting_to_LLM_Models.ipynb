# %% [markdown]
# <a href="https://colab.research.google.com/github/pavankumarcode/Mastering-AI/blob/main/1__Connecting_to_LLM_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
#from openai import OpenAI
#import anthropic
import google.genai as genai
from google.colab import userdata

userdata.get('GOOGLE_GEMINI_API_KEY')
print ('Import Done')
# Out:
# Import Done

# %%
# 3. GOOGLE (Gemini Pro/Flash Model Family)
def query_gemini(prompt,
                 model_name: str = 'gemini-3.6-flash',
                 temperature: float = 0.7,
                 max_output_tokens: int = 1024) -> str:
    """
    Connects to Google's Generative AI API.

    Foundations of AI:
    - Multimodal Readiness: Google's SDK is designed for multi-part content (text, image, video).
    - Massive Context: Ideal for passing entire repositories as context.
    """
    print(f"\n--- Querying Google ({model_name}) ---")

    api_key = userdata.get('GOOGLE_GEMINI_API_KEY')
    if not api_key:
        return "Error: GEMINI_API_KEY not found in Colab Secrets."

    try:
        # Note: We configure the library globally, but in production,
        # consider scoped client instances if available.
        client = genai.Client(api_key=api_key)
        response = client.models.generate_content(
            model=model_name,
            contents=prompt,
            config={
                'max_output_tokens': max_output_tokens,
                'temperature': temperature,
            }
        )
        #print(response)
        response_text = response.text
        #print(response_text)
        return response_text if response_text else "Error: Received empty response from the model."
    except Exception as e:
        return f"Gemini API Error: {str(e)}"

# %%
resposnse_text = query_gemini(prompt='Tell me about somthing about today, in less than 10 words.')
print(f'Response Received: [{resposnse_text}]')
# Out:
# --- Querying Google (gemini-3.6-flash) ---
# Response Received: [Today is the oldest you have ever been.]

# %% [markdown]
# """
# --- Querying Google (gemini-3.6-flash) ---
# Today is the youngest you will ever be.
# Today is the youngest you will ever be.
#
#
# --- Querying Google (gemini-3.6-flash) ---
# sdk_http_response=HttpResponse(
#   headers=<dict len=11>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text='Today is a clean slate filled with endless possibilities.',
#         thought_signature=b"\x12\xae\n\n\xab\n\x01\x11M2\x0f\xe1\xe9\x11'\xe2\xce\xeeH\xf4]\xf5<\x96\xe9\xe9\xc0\x88\xbcw\xd8\xc3;\x0c\xfa\x1b\x80\xea\xa6\xe0\xa2\x80\xba++\x8b\xe1\xbd\x187\x06/\xce\xdaV\x81\x93]\x12m\x08\xe0\xe6\x19\x0cU\xba\x92\x98\xe6\xdd\x17e`\x80\x98\xb3\xaa;\xf6\xb0\xdb\xab\xe6\xc77\xa0\x8a\x1bQ\xf6I\xf5\xaf].F...'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-3.6-flash' prompt_feedback=None response_id='jDCsaoHvB6uR-8YP57ajmQ4' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=10,
#   prompt_token_count=17,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=17
#     ),
#   ],
#   thoughts_token_count=373,
#   total_token_count=400
# ) model_status=None automatic_function_calling_history=[] parsed=None
# Today is a clean slate filled with endless possibilities.
# Response Received: [Today is a clean slate filled with endless possibilities.]
# \n\n--- Querying Google (gemini-3.6-flash) ---\nToday is the youngest you will ever be.\nToday is the youngest you will ever be.\n
#
# """
